# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("/Users/natemcdowell/Desktop/General/SchoolWork/year4/big_ideas/Big_Ideas_Final/parks_data/parks1.csv")

# %%
df.head()
# Out:
#    objectid_1  objectid   acreage           sqft          final_cat type  \
# 0        1202        36  0.959034   41775.367101  Neighborhood Park   NP
# 1        1203       198  2.060117   89738.347520  Neighborhood Park   NP
# 2        1204       158  0.468682   20415.724875  Neighborhood Park   NP
# 3        1205        72  1.955430   85178.182207  Neighborhood Park   NP
# 4        1206        87  5.108070  222506.623799  Neighborhood Park   NP
#
#    sector         origpkname                       updatepknm  \
# 0      15  Cliffside Parklet               August Wilson Park
# 1       2        Young Field                 Young Field Park
# 2       8       Revenue Park  Roland Lockridge Community Park
# 3      12    Friendship Park                  Friendship Park
# 4      12   Heths Playground                      Heth's Park
#
#                         alterntnam  ...                              globalid  \
# ...

# %%
for x in df:
    print(x)
# Out:
# objectid_1
# objectid
# acreage
# sqft
# final_cat
# type
# sector
# origpkname
# updatepknm
# alterntnam
# divname
# shape_leng
# globalid
# created_user
# created_date
# last_edited_user
# last_edited_date
# maintenanceresponsibility
# dpw_ac
# globalid_1
# shape_area
# shape_length

# %%
df = df[['objectid','sqft','origpkname','updatepknm','alterntnam']]

# %%
df.head()
# Out:
#    objectid           sqft         origpkname  \
# 0        36   41775.367101  Cliffside Parklet
# 1       198   89738.347520        Young Field
# 2       158   20415.724875       Revenue Park
# 3        72   85178.182207    Friendship Park
# 4        87  222506.623799   Heths Playground
#
#                         updatepknm                       alterntnam
# 0               August Wilson Park                   Cliffside Park
# 1                 Young Field Park                       Young Park
# 2  Roland Lockridge Community Park  Roland Lockridge Community Park
# 3                  Friendship Park                  Friendship Park
# 4                      Heth's Park                      Heth's Park

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df = df[["objectid","sqft",'updatepknm']]

# %%
df.rename(columns = {"updatepknm":"name"},inplace = True)

# %%
df.head()
# Out:
#    objectid           sqft                             name
# 0        36   41775.367101               August Wilson Park
# 1       198   89738.347520                 Young Field Park
# 2       158   20415.724875  Roland Lockridge Community Park
# 3        72   85178.182207                  Friendship Park
# 4        87  222506.623799                      Heth's Park

# %%
df.sort_values('name').reset_index()
# Out:
#      index  objectid          sqft                     name
# 0      101         1  7.228826e+04           Able Long Park
# 1      107         2  1.662005e+04  Albert Turk Graham Park
# 2       23       200  2.506040e+04               Alcoa Park
# 3      141        53  2.673959e+06        Allegheny Commons
# 4       44         4  9.955954e+04   Allegheny Landing Park
# ..     ...       ...           ...                      ...
# 210     16       195  2.598780e+03  Windermere Circle 1 & 2
# 211     78       196  1.069066e+05             Winters Park
# 212     68       197  1.690815e+04           Woods Run Park
# 213      1       198  8.973835e+04         Young Field Park
# 214     47       199  3.167868e+04              Zulema Park
#
# [215 rows x 4 columns]

# %%
df0 = pd.read_csv("/Users/natemcdowell/Desktop/General/SchoolWork/year4/big_ideas/Big_Ideas_Final/parks_data/parks2.csv")

# %%
df0.head()
# Out:
#            id                     name  type maintenance_responsibility  \
# 0  2111959181           Able Long Park  Park           Parks - Southern
# 1  1109513049  Albert Turk Graham Park  Park           Parks - Schenley
# 2  1544096765               Alcoa Park  Park           Parks - Northern
# 3  1212681573        Allegheny Commons  Park           Parks - Northern
# 4   954863286   Allegheny Landing Park  Park           Parks - Northern
#
#                                                image      neighborhood  \
# 0  https://tools.wprdc.org/images/pittsburgh/park...         Beechview
# 1  https://tools.wprdc.org/images/pittsburgh/park...  Crawford-Roberts
# 2                                                NaN       North Shore
# 3                                                NaN  Allegheny Center
# 4                                                NaN       North Shore
#
#    council_district  ward        tract  public_works_division  pli_division  \
# ...

# %%
df0 = df0[["id","name","neighborhood","latitude","longitude"]]

# %%
df0.head()
# Out:
#            id                     name      neighborhood   latitude  longitude
# 0  2111959181           Able Long Park         Beechview  40.408118 -80.028197
# 1  1109513049  Albert Turk Graham Park  Crawford-Roberts  40.440507 -79.984018
# 2  1544096765               Alcoa Park       North Shore  40.447481 -80.001017
# 3  1212681573        Allegheny Commons  Allegheny Center  40.453126 -80.009158
# 4   954863286   Allegheny Landing Park       North Shore  40.447184 -80.002907

# %%
merged = df.merge(df0,how='outer',on= "name")

# %%
sns.heatmap(merged.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
merged.dropna(inplace=True)

# %%
merged.drop(columns= ['objectid'],inplace=True)

# %%
merged
# Out:
#               sqft                                           name  \
# 0     41775.367101                             August Wilson Park
# 1     89738.347520                               Young Field Park
# 2     20415.724875                Roland Lockridge Community Park
# 3     85178.182207                                Friendship Park
# 4    222506.623799                                    Heth's Park
# ..             ...                                            ...
# 209   33806.365434  Brighton Heights Healthy Active Living Center
# 210   24995.236317                                  Arlington Gym
# 211   74980.569354                 Monongahela Wharf Landing Park
# 212    2457.023445         Emerald View Park - Shiloh Street Park
# 214  185956.140724                                  Homewood Park
#
#                id               neighborhood   latitude  longitude
# 0    1.366899e+09           Crawford-Roberts  40.446779 -79.985602
# ...

# %%
merged.neighborhood.value_counts().head(10).plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
park_sqft = merged.groupby(by='neighborhood')['sqft'].sum().head(10).sort_values(ascending = False).plot(kind='barh')

# %%
import geopandas
neighborhoods = geopandas.read_file("/Users/natemcdowell/Desktop/General/SchoolWork/year4/big_ideas/Data-Visualization/Neighborhoods/Neighborhoods_.shp") # read in the shapefile

# %%
print(merged.shape)
merged.head()
# Out:
# (205, 6)
#             sqft                             name            id  \
# 0   41775.367101               August Wilson Park  1.366899e+09
# 1   89738.347520                 Young Field Park  9.300681e+08
# 2   20415.724875  Roland Lockridge Community Park  8.672735e+08
# 3   85178.182207                  Friendship Park  1.424601e+09
# 4  222506.623799                      Heth's Park  1.479387e+09
#
#          neighborhood   latitude  longitude
# 0    Crawford-Roberts  40.446779 -79.985602
# 1  Marshall-Shadeland  40.472963 -80.032768
# 2       New Homestead  40.393932 -79.920736
# 3          Bloomfield  40.462562 -79.946161
# 4       Highland Park  40.477675 -79.927667

# %%
parks = pd.DataFrame(merged.groupby(by='neighborhood')['sqft'].sum().sort_values(ascending = False))

# %%
park_map = neighborhoods.merge(parks, how='left', left_on='hood', right_on='neighborhood')

# %%
park_map.plot(column='sqft', # set the data to be used for coloring
               cmap='OrRd',              # choose a color palette
               edgecolor="white",        # outline the districts in white
               legend=True,              # show the legend
               legend_kwds={'label': "sqft of parks"},
               figsize=(15, 10),         # set the size
               missing_kwds={"color": "lightgrey"} # set disctricts with no data to gray
               )
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Population

# %%
pop = pd.read_csv("/Users/natemcdowell/Desktop/General/SchoolWork/year4/big_ideas/Big_Ideas_Final/parks_data/population-density.csv")

# %%
pop.head()
# Out:
#         Neighborhood  Sector # Pop. 1940 Pop. 1950 Pop. 1960 Pop. 1970  \
# 0   Allegheny Center         3     4,521     3,862     2,512       632
# 1     Allegheny West         3     3,210     3,313     2,170     1,124
# 2          Allentown         6     8,227     7,487     6,416     5,361
# 3          Arlington         7     2,702     3,203     4,430     3,949
# 4  Arlington Heights         7     2,413     2,860     2,272     2,037
#
#   Pop. 1980 Pop. 1990 Pop. 2000 Pop. 2010  ... % Other (2010) % White (2010)  \
# 0     1,586     1,262       886       933  ...          0.64%         40.84%
# 1       820       654       508       462  ...          0.65%         76.62%
# 2     4,292     3,600     3,220     2,500  ...          0.80%         59.40%
# 3     2,294     2,210     1,999     1,869  ...          0.37%         76.46%
# 4     1,466     1,497       238       244  ...          1.64%          9.43%
#
# ...

# %%
print(pop.columns)
# Out:
# Index(['Neighborhood', 'Sector #', 'Pop. 1940', 'Pop. 1950', 'Pop. 1960',
#        'Pop. 1970', 'Pop. 1980', 'Pop. 1990', 'Pop. 2000', 'Pop. 2010',
#        '% Pop. Change, 60-70', '% Pop. Change, 70-80', '% Pop. Change, 80-90',
#        '% Pop. Change, 90-00', '% Pop. Change, 00-10',
#        'Pop. as % of City total (2010)', 'Land Area (sq. mi)',
#        'Land Area (acres)', 'Persons / sq. mi (2010)',
#        'Persons / sq. mi (2000)', 'Persons / acre (2010)',
#        'Persons / acre (2000)', '% African American (2010)', '% Asian (2010)',
#        '% Other (2010)', '% White (2010)', '% 2+ Races (2010)',
#        '% Hispanic (of any race) (2010)', '% Pop. Age < 5 (2010)',
#        '% Pop. Age 5-19 (2010)', '% Pop. Age 20-34 (2010)',
#        '% Pop. Age 35-59 (2010)', '% Pop. Age 60-74 (2010)',
#        '% Pop. Age > 75 (2010)'],
#       dtype='object')

# %%
pop = pop[['Neighborhood','Pop. 2010','Land Area (sq. mi)','Persons / sq. mi (2010)']]

# %%
pop.head()
# Out:
#         Neighborhood Pop. 2010  Land Area (sq. mi) Persons / sq. mi (2010)
# 0   Allegheny Center       933                 0.2                 4,442.9
# 1     Allegheny West       462                 0.1                 3,276.6
# 2          Allentown     2,500                 0.3                 8,474.6
# 3          Arlington     1,869                 0.5                 3,976.6
# 4  Arlington Heights       244                 0.1                 1,848.5

# %%
pop.rename(columns = {"Pop. 2010":"pop","Land Area (sq. mi)":"sqmi","Persons / sq. mi (2010)":"person_sqmi"}, inplace = True)

# %%
pop_map = neighborhoods.merge(pop, how='left', left_on='hood', right_on='Neighborhood')

# %%
# Cant get the legend to print properlt for some reason. 
pop_map.plot(column='person_sqmi', # set the data to be used for coloring
               cmap='OrRd',              # choose a color palette
               edgecolor="white",        # outline the districts in white
               #legend=,              # show the legend
               legend_kwds={'label': "person_sqmi"},
               figsize=(15, 10),         # set the size
               #missing_kwds={"color": "lightgrey"} # set disctricts with no data to gray
               )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## CrossWalks

# %%
cross = pd.read_csv("/Users/natemcdowell/Desktop/General/SchoolWork/year4/big_ideas/Big_Ideas_Final/parks_data/crosswalks.csv")

# %%
cross.head()
# Out:
#            id                   type           street inactive  \
# 0  1559483633      Crosswalk - Other      ELEVENTH ST        f
# 1   785965942  Crosswalk - Two Lined         PENN AVE        f
# 2  2008474459  Crosswalk - Two Lined  MORNINGSIDE AVE        f
# 3  1207933462  Crosswalk - Two Lined          TECH ST        f
# 4   905740180  Crosswalk - Two Lined          FREW ST        f
#
#                 neighborhood  council_district  ward        tract  \
# 0  Central Business District               6.0   2.0  42003020100
# 1             Strip District               7.0   2.0  42003020300
# 2                Morningside               7.0  10.0  42003101400
# 3        Squirrel Hill North               8.0  14.0  42003140100
# 4        Squirrel Hill South               5.0  14.0  42003980500
#
#    public_works_division  pli_division  police_zone fire_zone   latitude  \
# 0                    6.0           2.0          2.0       2-3  40.444989
# ...

# %%
total_walks = pd.DataFrame(cross.value_counts("neighborhood"))

# %%
total_walks.head(10).plot(kind="barh")
# Out:
# <AxesSubplot:ylabel='neighborhood'>

# %%
cross_map = neighborhoods.merge(total_walks, how='left', left_on='hood', right_on='neighborhood')

# %%
cross_map.plot(column=0, # set the data to be used for coloring
               cmap='OrRd',              # choose a color palette
               edgecolor="white",        # outline the districts in white
               #legend=,              # show the legend
               legend_kwds={'label': "person_sqmi"},
               figsize=(15, 10),         # set the size
               #missing_kwds={"color": "lightgrey"} # set disctricts with no data to gray
               )
# Out:
# <AxesSubplot:>

# %% [markdown]
# # for next time
# If i want to inlcude crosswalks I need to divide total crosswalks by the area of the nieghborhood as this would create a more accuarate metric. To create rankings/scores for the neighborhoods it might be helpful to normalize the data between (1-10) and round to two decimal points. You could then create three maps of the seperate metrics then a map of cumulative scores to show the best "neighborhood". Could also inlude other statistical tests to determine the actual best neighborhood.
